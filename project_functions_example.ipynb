# %%
#!pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 6.5MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=c62ec326c2f94ee0b0f252bb46c49bd40a5ec94c03b4c90b060ca9b1c7d5e4de
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
googl = yf.Ticker('GOOGL')
googl_df = googl.history(period='max')
googl_df.head()
# Out:
#                  Open       High        Low  ...    Volume  Dividends  Stock Splits
# Date                                         ...
# 2004-08-19  50.050049  52.082081  48.028027  ...  44659096          0           0.0
# 2004-08-20  50.555557  54.594597  50.300301  ...  22834343          0           0.0
# 2004-08-23  55.430431  56.796799  54.579578  ...  18256126          0           0.0
# 2004-08-24  55.675674  55.855858  51.836838  ...  15247337          0           0.0
# 2004-08-25  52.532532  54.054054  51.991993  ...   9188602          0           0.0
#
# [5 rows x 7 columns]

# %%
def rolling_aves(stock_df):

    # Generate columns for 5 day means using pandas rolling  
    stock_df['5 Day Open Mean'] = stock_df['Open'].rolling(5).mean()
    stock_df['5 Day High Mean'] = stock_df['High'].rolling(5).mean()
    stock_df['5 Day Low Mean'] = stock_df['Low'].rolling(5).mean()
    stock_df['5 Day Close Mean'] = stock_df['Close'].rolling(5).mean()
    stock_df['5 Day Volume Mean'] = stock_df['Volume'].rolling(5).mean()
    
    # Correct for first 4 days where rolling produces NaN
    stock_df['5 Day Open Mean'][0] = stock_df['Open'][0]
    stock_df['5 Day Open Mean'][1] = np.mean(stock_df['Open'][0:1])
    stock_df['5 Day Open Mean'][2] = np.mean(stock_df['Open'][0:2])
    stock_df['5 Day Open Mean'][3] = np.mean(stock_df['Open'][0:3])
    
    stock_df['5 Day High Mean'][0] = stock_df['High'][0]
    stock_df['5 Day High Mean'][1] = np.mean(stock_df['High'][0:1])
    stock_df['5 Day High Mean'][2] = np.mean(stock_df['High'][0:2])
    stock_df['5 Day High Mean'][3] = np.mean(stock_df['High'][0:3])
    
    stock_df['5 Day Low Mean'][0] = stock_df['Low'][0]
    stock_df['5 Day Low Mean'][1] = np.mean(stock_df['Low'][0:1])
    stock_df['5 Day Low Mean'][2] = np.mean(stock_df['Low'][0:2])
    stock_df['5 Day Low Mean'][3] = np.mean(stock_df['Low'][0:3])
    
    stock_df['5 Day Close Mean'][0] = stock_df['Close'][0]
    stock_df['5 Day Close Mean'][1] = np.mean(stock_df['Close'][0:1])
    stock_df['5 Day Close Mean'][2] = np.mean(stock_df['Close'][0:2])
    stock_df['5 Day Close Mean'][3] = np.mean(stock_df['Close'][0:3])
    
    stock_df['5 Day Volume Mean'][0] = stock_df['Volume'][0]
    stock_df['5 Day Volume Mean'][1] = np.mean(stock_df['Volume'][0:1])
    stock_df['5 Day Volume Mean'][2] = np.mean(stock_df['Volume'][0:2])
    stock_df['5 Day Volume Mean'][3] = np.mean(stock_df['Volume'][0:3])
    
    # Produce columns for 5 day var using rolling 
    stock_df['5 Day Open Var'] = stock_df['Open'].rolling(5).var()
    stock_df['5 Day High Var'] = stock_df['High'].rolling(5).var()
    stock_df['5 Day Low Var'] = stock_df['Low'].rolling(5).var()
    stock_df['5 Day Close Var'] = stock_df['Close'].rolling(5).var()
    stock_df['5 Day Volume Var'] = stock_df['Volume'].rolling(5).var()
    
    # Correct for first 4 days where rolling produces NaN
    stock_df['5 Day Open Var'][0] = 0
    stock_df['5 Day Open Var'][1] = np.var(stock_df['Open'][0:1])
    stock_df['5 Day Open Var'][2] = np.var(stock_df['Open'][0:2])
    stock_df['5 Day Open Var'][3] = np.var(stock_df['Open'][0:3])
    
    stock_df['5 Day High Var'][0] = 0
    stock_df['5 Day High Var'][1] = np.var(stock_df['High'][0:1])
    stock_df['5 Day High Var'][2] = np.var(stock_df['High'][0:2])
    stock_df['5 Day High Var'][3] = np.var(stock_df['High'][0:3])
    
    stock_df['5 Day Low Var'][0] = 0
    stock_df['5 Day Low Var'][1] = np.var(stock_df['Low'][0:1])
    stock_df['5 Day Low Var'][2] = np.var(stock_df['Low'][0:2])
    stock_df['5 Day Low Var'][3] = np.var(stock_df['Low'][0:3])
    
    stock_df['5 Day Close Var'][0] = 0
    stock_df['5 Day Close Var'][1] = np.var(stock_df['Close'][0:1])
    stock_df['5 Day Close Var'][2] = np.var(stock_df['Close'][0:2])
    stock_df['5 Day Close Var'][3] = np.var(stock_df['Close'][0:3])
    
    stock_df['5 Day Volume Var'][0] = 0
    stock_df['5 Day Volume Var'][1] = np.var(stock_df['Volume'][0:1])
    stock_df['5 Day Volume Var'][2] = np.var(stock_df['Volume'][0:2])
    stock_df['5 Day Volume Var'][3] = np.var(stock_df['Volume'][0:3])
    
    # Create 10 day means
    stock_df['10 Day Open Mean'] = stock_df['Open'].rolling(10).mean()
    stock_df['10 Day High Mean'] = stock_df['High'].rolling(10).mean()
    stock_df['10 Day Low Mean'] = stock_df['Low'].rolling(10).mean()
    stock_df['10 Day Close Mean'] = stock_df['Close'].rolling(10).mean()
    stock_df['10 Day Volume Mean'] = stock_df['Volume'].rolling(10).mean()
    
    # Correct first 9 days where rolling produces NaN
    stock_df['10 Day Open Mean'][0] = stock_df['Open'][0]
    stock_df['10 Day Open Mean'][1] = np.mean(stock_df['Open'][0:1])
    stock_df['10 Day Open Mean'][2] = np.mean(stock_df['Open'][0:2])
    stock_df['10 Day Open Mean'][3] = np.mean(stock_df['Open'][0:3])
    stock_df['10 Day Open Mean'][4] = np.mean(stock_df['Open'][0:4])
    stock_df['10 Day Open Mean'][5] = np.mean(stock_df['Open'][0:5])
    stock_df['10 Day Open Mean'][6] = np.mean(stock_df['Open'][0:6])
    stock_df['10 Day Open Mean'][7] = np.mean(stock_df['Open'][0:7])
    stock_df['10 Day Open Mean'][8] = np.mean(stock_df['Open'][0:8])
    
    stock_df['10 Day High Mean'][0] = stock_df['High'][0]
    stock_df['10 Day High Mean'][1] = np.mean(stock_df['High'][0:1])
    stock_df['10 Day High Mean'][2] = np.mean(stock_df['High'][0:2])
    stock_df['10 Day High Mean'][3] = np.mean(stock_df['High'][0:3])
    stock_df['10 Day High Mean'][4] = np.mean(stock_df['High'][0:4])
    stock_df['10 Day High Mean'][5] = np.mean(stock_df['High'][0:5])
    stock_df['10 Day High Mean'][6] = np.mean(stock_df['High'][0:6])
    stock_df['10 Day High Mean'][7] = np.mean(stock_df['High'][0:7])
    stock_df['10 Day High Mean'][8] = np.mean(stock_df['High'][0:8])
    
    stock_df['10 Day Low Mean'][0] = stock_df['Low'][0]
    stock_df['10 Day Low Mean'][1] = np.mean(stock_df['Low'][0:1])
    stock_df['10 Day Low Mean'][2] = np.mean(stock_df['Low'][0:2])
    stock_df['10 Day Low Mean'][3] = np.mean(stock_df['Low'][0:3])
    stock_df['10 Day Low Mean'][4] = np.mean(stock_df['Low'][0:4])
    stock_df['10 Day Low Mean'][5] = np.mean(stock_df['Low'][0:5])
    stock_df['10 Day Low Mean'][6] = np.mean(stock_df['Low'][0:6])
    stock_df['10 Day Low Mean'][7] = np.mean(stock_df['Low'][0:7])
    stock_df['10 Day Low Mean'][8] = np.mean(stock_df['Low'][0:8])
    
    stock_df['10 Day Close Mean'][0] = stock_df['Close'][0]
    stock_df['10 Day Close Mean'][1] = np.mean(stock_df['Close'][0:1])
    stock_df['10 Day Close Mean'][2] = np.mean(stock_df['Close'][0:2])
    stock_df['10 Day Close Mean'][3] = np.mean(stock_df['Close'][0:3])
    stock_df['10 Day Close Mean'][4] = np.mean(stock_df['Close'][0:4])
    stock_df['10 Day Close Mean'][5] = np.mean(stock_df['Close'][0:5])
    stock_df['10 Day Close Mean'][6] = np.mean(stock_df['Close'][0:6])
    stock_df['10 Day Close Mean'][7] = np.mean(stock_df['Close'][0:7])
    stock_df['10 Day Close Mean'][8] = np.mean(stock_df['Close'][0:8])
    
    stock_df['10 Day Volume Mean'][0] = stock_df['Volume'][0]
    stock_df['10 Day Volume Mean'][1] = np.mean(stock_df['Volume'][0:1])
    stock_df['10 Day Volume Mean'][2] = np.mean(stock_df['Volume'][0:2])
    stock_df['10 Day Volume Mean'][3] = np.mean(stock_df['Volume'][0:3])
    stock_df['10 Day Volume Mean'][4] = np.mean(stock_df['Volume'][0:4])
    stock_df['10 Day Volume Mean'][5] = np.mean(stock_df['Volume'][0:5])
    stock_df['10 Day Volume Mean'][6] = np.mean(stock_df['Volume'][0:6])
    stock_df['10 Day Volume Mean'][7] = np.mean(stock_df['Volume'][0:7])
    stock_df['10 Day Volume Mean'][8] = np.mean(stock_df['Volume'][0:8])
    
    # produce 10 day var columns
    stock_df['10 Day Open Var'] = stock_df['Open'].rolling(10).var()
    stock_df['10 Day High Var'] = stock_df['High'].rolling(10).var()
    stock_df['10 Day Low Var'] = stock_df['Low'].rolling(10).var()
    stock_df['10 Day Close Var'] = stock_df['Close'].rolling(10).var()
    stock_df['10 Day Volume Var'] = stock_df['Volume'].rolling(10).var()
    
    # correct for first 9 days where rolling produces NaN
    stock_df['10 Day Open Var'][0] = 0
    stock_df['10 Day Open Var'][1] = np.var(stock_df['Open'][0:1])
    stock_df['10 Day Open Var'][2] = np.var(stock_df['Open'][0:2])
    stock_df['10 Day Open Var'][3] = np.var(stock_df['Open'][0:3])
    stock_df['10 Day Open Var'][4] = np.var(stock_df['Open'][0:4])
    stock_df['10 Day Open Var'][5] = np.var(stock_df['Open'][0:5])
    stock_df['10 Day Open Var'][6] = np.var(stock_df['Open'][0:6])
    stock_df['10 Day Open Var'][7] = np.var(stock_df['Open'][0:7])
    stock_df['10 Day Open Var'][8] = np.var(stock_df['Open'][0:8])
    
    stock_df['10 Day High Var'][0] = 0
    stock_df['10 Day High Var'][1] = np.var(stock_df['High'][0:1])
    stock_df['10 Day High Var'][2] = np.var(stock_df['High'][0:2])
    stock_df['10 Day High Var'][3] = np.var(stock_df['High'][0:3])
    stock_df['10 Day High Var'][4] = np.var(stock_df['High'][0:4])
    stock_df['10 Day High Var'][5] = np.var(stock_df['High'][0:5])
    stock_df['10 Day High Var'][6] = np.var(stock_df['High'][0:6])
    stock_df['10 Day High Var'][7] = np.var(stock_df['High'][0:7])
    stock_df['10 Day High Var'][8] = np.var(stock_df['High'][0:8])
    
    stock_df['10 Day Low Var'][0] = 0
    stock_df['10 Day Low Var'][1] = np.var(stock_df['Low'][0:1])
    stock_df['10 Day Low Var'][2] = np.var(stock_df['Low'][0:2])
    stock_df['10 Day Low Var'][3] = np.var(stock_df['Low'][0:3])
    stock_df['10 Day Low Var'][4] = np.var(stock_df['Low'][0:4])
    stock_df['10 Day Low Var'][5] = np.var(stock_df['Low'][0:5])
    stock_df['10 Day Low Var'][6] = np.var(stock_df['Low'][0:6])
    stock_df['10 Day Low Var'][7] = np.var(stock_df['Low'][0:7])
    stock_df['10 Day Low Var'][8] = np.var(stock_df['Low'][0:8])
    
    stock_df['10 Day Close Var'][0] = 0
    stock_df['10 Day Close Var'][1] = np.var(stock_df['Close'][0:1])
    stock_df['10 Day Close Var'][2] = np.var(stock_df['Close'][0:2])
    stock_df['10 Day Close Var'][3] = np.var(stock_df['Close'][0:3])
    stock_df['10 Day Close Var'][4] = np.var(stock_df['Close'][0:4])
    stock_df['10 Day Close Var'][5] = np.var(stock_df['Close'][0:5])
    stock_df['10 Day Close Var'][6] = np.var(stock_df['Close'][0:6])
    stock_df['10 Day Close Var'][7] = np.var(stock_df['Close'][0:7])
    stock_df['10 Day Close Var'][8] = np.var(stock_df['Close'][0:8])
    
    stock_df['10 Day Volume Var'][0] = 0
    stock_df['10 Day Volume Var'][1] = np.var(stock_df['Volume'][0:1])
    stock_df['10 Day Volume Var'][2] = np.var(stock_df['Volume'][0:2])
    stock_df['10 Day Volume Var'][3] = np.var(stock_df['Volume'][0:3])
    stock_df['10 Day Volume Var'][4] = np.var(stock_df['Volume'][0:4])
    stock_df['10 Day Volume Var'][5] = np.var(stock_df['Volume'][0:5])
    stock_df['10 Day Volume Var'][6] = np.var(stock_df['Volume'][0:6])
    stock_df['10 Day Volume Var'][7] = np.var(stock_df['Volume'][0:7])
    stock_df['10 Day Volume Var'][8] = np.var(stock_df['Volume'][0:8])
    
    # Produce 20 day mean columns
    stock_df['20 Day Open Mean'] = stock_df['Open'].rolling(20).mean()
    stock_df['20 Day High Mean'] = stock_df['High'].rolling(20).mean()
    stock_df['20 Day Low Mean'] = stock_df['Low'].rolling(20).mean()
    stock_df['20 Day Close Mean'] = stock_df['Close'].rolling(20).mean()
    stock_df['20 Day Volume Mean'] = stock_df['Volume'].rolling(20).mean()
    
    # correct for first 19 days where rolling produces NaN
    stock_df['20 Day Open Mean'][0] = stock_df['Open'][0]
    stock_df['20 Day Open Mean'][1] = np.mean(stock_df['Open'][0:1])
    stock_df['20 Day Open Mean'][2] = np.mean(stock_df['Open'][0:2])
    stock_df['20 Day Open Mean'][3] = np.mean(stock_df['Open'][0:3])
    stock_df['20 Day Open Mean'][4] = np.mean(stock_df['Open'][0:4])
    stock_df['20 Day Open Mean'][5] = np.mean(stock_df['Open'][0:5])
    stock_df['20 Day Open Mean'][6] = np.mean(stock_df['Open'][0:6])
    stock_df['20 Day Open Mean'][7] = np.mean(stock_df['Open'][0:7])
    stock_df['20 Day Open Mean'][8] = np.mean(stock_df['Open'][0:8])
    stock_df['20 Day Open Mean'][9] = np.mean(stock_df['Open'][0:9])
    stock_df['20 Day Open Mean'][10] = np.mean(stock_df['Open'][0:10])
    stock_df['20 Day Open Mean'][11] = np.mean(stock_df['Open'][0:11])
    stock_df['20 Day Open Mean'][12] = np.mean(stock_df['Open'][0:12])
    stock_df['20 Day Open Mean'][13] = np.mean(stock_df['Open'][0:13])
    stock_df['20 Day Open Mean'][14] = np.mean(stock_df['Open'][0:14])
    stock_df['20 Day Open Mean'][15] = np.mean(stock_df['Open'][0:15])
    stock_df['20 Day Open Mean'][16] = np.mean(stock_df['Open'][0:16])
    stock_df['20 Day Open Mean'][17] = np.mean(stock_df['Open'][0:17])
    stock_df['20 Day Open Mean'][18] = np.mean(stock_df['Open'][0:18])
    
    
    stock_df['20 Day High Mean'][0] = stock_df['High'][0]
    stock_df['20 Day High Mean'][1] = np.mean(stock_df['High'][0:1])
    stock_df['20 Day High Mean'][2] = np.mean(stock_df['High'][0:2])
    stock_df['20 Day High Mean'][3] = np.mean(stock_df['High'][0:3])
    stock_df['20 Day High Mean'][4] = np.mean(stock_df['High'][0:4])
    stock_df['20 Day High Mean'][5] = np.mean(stock_df['High'][0:5])
    stock_df['20 Day High Mean'][6] = np.mean(stock_df['High'][0:6])
    stock_df['20 Day High Mean'][7] = np.mean(stock_df['High'][0:7])
    stock_df['20 Day High Mean'][8] = np.mean(stock_df['High'][0:8])
    stock_df['20 Day High Mean'][9] = np.mean(stock_df['High'][0:9])
    stock_df['20 Day High Mean'][10] = np.mean(stock_df['High'][0:10])
    stock_df['20 Day High Mean'][11] = np.mean(stock_df['High'][0:11])
    stock_df['20 Day High Mean'][12] = np.mean(stock_df['High'][0:12])
    stock_df['20 Day High Mean'][13] = np.mean(stock_df['High'][0:13])
    stock_df['20 Day High Mean'][14] = np.mean(stock_df['High'][0:14])
    stock_df['20 Day High Mean'][15] = np.mean(stock_df['High'][0:15])
    stock_df['20 Day High Mean'][16] = np.mean(stock_df['High'][0:16])
    stock_df['20 Day High Mean'][17] = np.mean(stock_df['High'][0:17])
    stock_df['20 Day High Mean'][18] = np.mean(stock_df['High'][0:18])
    
    stock_df['20 Day Low Mean'][0] = stock_df['Low'][0]
    stock_df['20 Day Low Mean'][1] = np.mean(stock_df['Low'][0:1])
    stock_df['20 Day Low Mean'][2] = np.mean(stock_df['Low'][0:2])
    stock_df['20 Day Low Mean'][3] = np.mean(stock_df['Low'][0:3])
    stock_df['20 Day Low Mean'][4] = np.mean(stock_df['Low'][0:4])
    stock_df['20 Day Low Mean'][5] = np.mean(stock_df['Low'][0:5])
    stock_df['20 Day Low Mean'][6] = np.mean(stock_df['Low'][0:6])
    stock_df['20 Day Low Mean'][7] = np.mean(stock_df['Low'][0:7])
    stock_df['20 Day Low Mean'][8] = np.mean(stock_df['Low'][0:8])
    stock_df['20 Day Low Mean'][9] = np.mean(stock_df['Low'][0:9])
    stock_df['20 Day Low Mean'][10] = np.mean(stock_df['Low'][0:10])
    stock_df['20 Day Low Mean'][11] = np.mean(stock_df['Low'][0:11])
    stock_df['20 Day Low Mean'][12] = np.mean(stock_df['Low'][0:12])
    stock_df['20 Day Low Mean'][13] = np.mean(stock_df['Low'][0:13])
    stock_df['20 Day Low Mean'][14] = np.mean(stock_df['Low'][0:14])
    stock_df['20 Day Low Mean'][15] = np.mean(stock_df['Low'][0:15])
    stock_df['20 Day Low Mean'][16] = np.mean(stock_df['Low'][0:16])
    stock_df['20 Day Low Mean'][17] = np.mean(stock_df['Low'][0:17])
    stock_df['20 Day Low Mean'][18] = np.mean(stock_df['Low'][0:18])
    
    stock_df['20 Day Close Mean'][0] = stock_df['Close'][0]
    stock_df['20 Day Close Mean'][1] = np.mean(stock_df['Close'][0:1])
    stock_df['20 Day Close Mean'][2] = np.mean(stock_df['Close'][0:2])
    stock_df['20 Day Close Mean'][3] = np.mean(stock_df['Close'][0:3])
    stock_df['20 Day Close Mean'][4] = np.mean(stock_df['Close'][0:4])
    stock_df['20 Day Close Mean'][5] = np.mean(stock_df['Close'][0:5])
    stock_df['20 Day Close Mean'][6] = np.mean(stock_df['Close'][0:6])
    stock_df['20 Day Close Mean'][7] = np.mean(stock_df['Close'][0:7])
    stock_df['20 Day Close Mean'][8] = np.mean(stock_df['Close'][0:8])
    stock_df['20 Day Close Mean'][9] = np.mean(stock_df['Close'][0:9])
    stock_df['20 Day Close Mean'][10] = np.mean(stock_df['Close'][0:10])
    stock_df['20 Day Close Mean'][11] = np.mean(stock_df['Close'][0:11])
    stock_df['20 Day Close Mean'][12] = np.mean(stock_df['Close'][0:12])
    stock_df['20 Day Close Mean'][13] = np.mean(stock_df['Close'][0:13])
    stock_df['20 Day Close Mean'][14] = np.mean(stock_df['Close'][0:14])
    stock_df['20 Day Close Mean'][15] = np.mean(stock_df['Close'][0:15])
    stock_df['20 Day Close Mean'][16] = np.mean(stock_df['Close'][0:16])
    stock_df['20 Day Close Mean'][17] = np.mean(stock_df['Close'][0:17])
    stock_df['20 Day Close Mean'][18] = np.mean(stock_df['Close'][0:18])
    
    stock_df['20 Day Volume Mean'][0] = stock_df['Volume'][0]
    stock_df['20 Day Volume Mean'][1] = np.mean(stock_df['Volume'][0:1])
    stock_df['20 Day Volume Mean'][2] = np.mean(stock_df['Volume'][0:2])
    stock_df['20 Day Volume Mean'][3] = np.mean(stock_df['Volume'][0:3])
    stock_df['20 Day Volume Mean'][4] = np.mean(stock_df['Volume'][0:4])
    stock_df['20 Day Volume Mean'][5] = np.mean(stock_df['Volume'][0:5])
    stock_df['20 Day Volume Mean'][6] = np.mean(stock_df['Volume'][0:6])
    stock_df['20 Day Volume Mean'][7] = np.mean(stock_df['Volume'][0:7])
    stock_df['20 Day Volume Mean'][8] = np.mean(stock_df['Volume'][0:8])
    stock_df['20 Day Volume Mean'][9] = np.mean(stock_df['Volume'][0:9])
    stock_df['20 Day Volume Mean'][10] = np.mean(stock_df['Volume'][0:10])
    stock_df['20 Day Volume Mean'][11] = np.mean(stock_df['Volume'][0:11])
    stock_df['20 Day Volume Mean'][12] = np.mean(stock_df['Volume'][0:12])
    stock_df['20 Day Volume Mean'][13] = np.mean(stock_df['Volume'][0:13])
    stock_df['20 Day Volume Mean'][14] = np.mean(stock_df['Volume'][0:14])
    stock_df['20 Day Volume Mean'][15] = np.mean(stock_df['Volume'][0:15])
    stock_df['20 Day Volume Mean'][16] = np.mean(stock_df['Volume'][0:16])
    stock_df['20 Day Volume Mean'][17] = np.mean(stock_df['Volume'][0:17])
    stock_df['20 Day Volume Mean'][18] = np.mean(stock_df['Volume'][0:18])
    
    # Produce columns for 20 day var
    stock_df['20 Day Open Var'] = stock_df['Open'].rolling(20).var()
    stock_df['20 Day High Var'] = stock_df['High'].rolling(20).var()
    stock_df['20 Day Low Var'] = stock_df['Low'].rolling(20).var()
    stock_df['20 Day Close Var'] = stock_df['Close'].rolling(20).var()
    stock_df['20 Day Volume Var'] = stock_df['Volume'].rolling(20).var()
    
    # Correct first 19 columns where NaN
    stock_df['20 Day Open Var'][0] = 0
    stock_df['20 Day Open Var'][1] = np.var(stock_df['Open'][0:1])
    stock_df['20 Day Open Var'][2] = np.var(stock_df['Open'][0:2])
    stock_df['20 Day Open Var'][3] = np.var(stock_df['Open'][0:3])
    stock_df['20 Day Open Var'][4] = np.var(stock_df['Open'][0:4])
    stock_df['20 Day Open Var'][5] = np.var(stock_df['Open'][0:5])
    stock_df['20 Day Open Var'][6] = np.var(stock_df['Open'][0:6])
    stock_df['20 Day Open Var'][7] = np.var(stock_df['Open'][0:7])
    stock_df['20 Day Open Var'][8] = np.var(stock_df['Open'][0:8])
    stock_df['20 Day Open Var'][9] = np.var(stock_df['Open'][0:9])
    stock_df['20 Day Open Var'][10] = np.var(stock_df['Open'][0:10])
    stock_df['20 Day Open Var'][11] = np.var(stock_df['Open'][0:11])
    stock_df['20 Day Open Var'][12] = np.var(stock_df['Open'][0:12])
    stock_df['20 Day Open Var'][13] = np.var(stock_df['Open'][0:13])
    stock_df['20 Day Open Var'][14] = np.var(stock_df['Open'][0:14])
    stock_df['20 Day Open Var'][15] = np.var(stock_df['Open'][0:15])
    stock_df['20 Day Open Var'][16] = np.var(stock_df['Open'][0:16])
    stock_df['20 Day Open Var'][17] = np.var(stock_df['Open'][0:17])
    stock_df['20 Day Open Var'][18] = np.var(stock_df['Open'][0:18])
    
    stock_df['20 Day High Var'][0] = 0
    stock_df['20 Day High Var'][1] = np.var(stock_df['High'][0:1])
    stock_df['20 Day High Var'][2] = np.var(stock_df['High'][0:2])
    stock_df['20 Day High Var'][3] = np.var(stock_df['High'][0:3])
    stock_df['20 Day High Var'][4] = np.var(stock_df['High'][0:4])
    stock_df['20 Day High Var'][5] = np.var(stock_df['High'][0:5])
    stock_df['20 Day High Var'][6] = np.var(stock_df['High'][0:6])
    stock_df['20 Day High Var'][7] = np.var(stock_df['High'][0:7])
    stock_df['20 Day High Var'][8] = np.var(stock_df['High'][0:8])
    stock_df['20 Day High Var'][9] = np.var(stock_df['High'][0:9])
    stock_df['20 Day High Var'][10] = np.var(stock_df['High'][0:10])
    stock_df['20 Day High Var'][11] = np.var(stock_df['High'][0:11])
    stock_df['20 Day High Var'][12] = np.var(stock_df['High'][0:12])
    stock_df['20 Day High Var'][13] = np.var(stock_df['High'][0:13])
    stock_df['20 Day High Var'][14] = np.var(stock_df['High'][0:14])
    stock_df['20 Day High Var'][15] = np.var(stock_df['High'][0:15])
    stock_df['20 Day High Var'][16] = np.var(stock_df['High'][0:16])
    stock_df['20 Day High Var'][17] = np.var(stock_df['High'][0:17])
    stock_df['20 Day High Var'][18] = np.var(stock_df['High'][0:18])
    
    stock_df['20 Day Low Var'][0] = 0
    stock_df['20 Day Low Var'][1] = np.var(stock_df['Low'][0:1])
    stock_df['20 Day Low Var'][2] = np.var(stock_df['Low'][0:2])
    stock_df['20 Day Low Var'][3] = np.var(stock_df['Low'][0:3])
    stock_df['20 Day Low Var'][4] = np.var(stock_df['Low'][0:4])
    stock_df['20 Day Low Var'][5] = np.var(stock_df['Low'][0:5])
    stock_df['20 Day Low Var'][6] = np.var(stock_df['Low'][0:6])
    stock_df['20 Day Low Var'][7] = np.var(stock_df['Low'][0:7])
    stock_df['20 Day Low Var'][8] = np.var(stock_df['Low'][0:8])
    stock_df['20 Day Low Var'][9] = np.var(stock_df['Low'][0:9])
    stock_df['20 Day Low Var'][10] = np.var(stock_df['Low'][0:10])
    stock_df['20 Day Low Var'][11] = np.var(stock_df['Low'][0:11])
    stock_df['20 Day Low Var'][12] = np.var(stock_df['Low'][0:12])
    stock_df['20 Day Low Var'][13] = np.var(stock_df['Low'][0:13])
    stock_df['20 Day Low Var'][14] = np.var(stock_df['Low'][0:14])
    stock_df['20 Day Low Var'][15] = np.var(stock_df['Low'][0:15])
    stock_df['20 Day Low Var'][16] = np.var(stock_df['Low'][0:16])
    stock_df['20 Day Low Var'][17] = np.var(stock_df['Low'][0:17])
    stock_df['20 Day Low Var'][18] = np.var(stock_df['Low'][0:18])
    
    stock_df['20 Day Close Var'][0] = 0
    stock_df['20 Day Close Var'][1] = np.var(stock_df['Close'][0:1])
    stock_df['20 Day Close Var'][2] = np.var(stock_df['Close'][0:2])
    stock_df['20 Day Close Var'][3] = np.var(stock_df['Close'][0:3])
    stock_df['20 Day Close Var'][4] = np.var(stock_df['Close'][0:4])
    stock_df['20 Day Close Var'][5] = np.var(stock_df['Close'][0:5])
    stock_df['20 Day Close Var'][6] = np.var(stock_df['Close'][0:6])
    stock_df['20 Day Close Var'][7] = np.var(stock_df['Close'][0:7])
    stock_df['20 Day Close Var'][8] = np.var(stock_df['Close'][0:8])
    stock_df['20 Day Close Var'][9] = np.var(stock_df['Close'][0:9])
    stock_df['20 Day Close Var'][10] = np.var(stock_df['Close'][0:10])
    stock_df['20 Day Close Var'][11] = np.var(stock_df['Close'][0:11])
    stock_df['20 Day Close Var'][12] = np.var(stock_df['Close'][0:12])
    stock_df['20 Day Close Var'][13] = np.var(stock_df['Close'][0:13])
    stock_df['20 Day Close Var'][14] = np.var(stock_df['Close'][0:14])
    stock_df['20 Day Close Var'][15] = np.var(stock_df['Close'][0:15])
    stock_df['20 Day Close Var'][16] = np.var(stock_df['Close'][0:16])
    stock_df['20 Day Close Var'][17] = np.var(stock_df['Close'][0:17])
    stock_df['20 Day Close Var'][18] = np.var(stock_df['Close'][0:18])
    
    stock_df['20 Day Volume Var'][0] = 0
    stock_df['20 Day Volume Var'][1] = np.var(stock_df['Volume'][0:1])
    stock_df['20 Day Volume Var'][2] = np.var(stock_df['Volume'][0:2])
    stock_df['20 Day Volume Var'][3] = np.var(stock_df['Volume'][0:3])
    stock_df['20 Day Volume Var'][4] = np.var(stock_df['Volume'][0:4])
    stock_df['20 Day Volume Var'][5] = np.var(stock_df['Volume'][0:5])
    stock_df['20 Day Volume Var'][6] = np.var(stock_df['Volume'][0:6])
    stock_df['20 Day Volume Var'][7] = np.var(stock_df['Volume'][0:7])
    stock_df['20 Day Volume Var'][8] = np.var(stock_df['Volume'][0:8])
    stock_df['20 Day Volume Var'][9] = np.var(stock_df['Volume'][0:9])
    stock_df['20 Day Volume Var'][10] = np.var(stock_df['Volume'][0:10])
    stock_df['20 Day Volume Var'][11] = np.var(stock_df['Volume'][0:11])
    stock_df['20 Day Volume Var'][12] = np.var(stock_df['Volume'][0:12])
    stock_df['20 Day Volume Var'][13] = np.var(stock_df['Volume'][0:13])
    stock_df['20 Day Volume Var'][14] = np.var(stock_df['Volume'][0:14])
    stock_df['20 Day Volume Var'][15] = np.var(stock_df['Volume'][0:15])
    stock_df['20 Day Volume Var'][16] = np.var(stock_df['Volume'][0:16])
    stock_df['20 Day Volume Var'][17] = np.var(stock_df['Volume'][0:17])
    stock_df['20 Day Volume Var'][18] = np.var(stock_df['Volume'][0:18])
    
    stock_df['20 Day Open Var'] = stock_df['Open'].rolling(20).var()
    stock_df['20 Day High Var'] = stock_df['High'].rolling(20).var()
    stock_df['20 Day Low Var'] = stock_df['Low'].rolling(20).var()
    stock_df['20 Day Close Var'] = stock_df['Close'].rolling(20).var()
    stock_df['20 Day Volume Var'] = stock_df['Volume'].rolling(20).var()
    
    return stock_df

# %%
googl_df = rolling_aves(googl_df)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
def date_time_prep(stock_df):
  # Makes columns for day/month/year from datetime index
  stock_df['Day'] = stock_df.index.day
  stock_df['Month'] = stock_df.index.month
  stock_df['Year'] = stock_df.index.year

  # Calculates the number of days since IPO
  stock_df['Days From IPO'] = (stock_df.index - stock_df.index[0]).days

  return stock_df

# %%
googl_df = date_time_prep(googl_df)
googl_df
# Out:
#                    Open         High  ...  Close in 1Days  Close in 5Days
# Date                                  ...
# 2004-08-19    50.050049    52.082081  ...       54.209209       54.009010
# 2004-08-20    50.555557    54.594597  ...       54.754753       53.128128
# 2004-08-23    55.430431    56.796799  ...       52.487488       51.056057
# 2004-08-24    55.675674    55.855858  ...       53.053055       51.236237
# 2004-08-25    52.532532    54.054054  ...       54.009010       50.175175
# ...                 ...          ...  ...             ...             ...
# 2021-02-08  2100.000000  2115.000000  ...     2075.389893             NaN
# 2021-02-09  2074.800049  2098.510010  ...     2086.479980             NaN
# 2021-02-10  2083.139893  2098.879883  ...     2088.750000             NaN
# 2021-02-11  2091.000000  2094.000000  ...     2095.030029             NaN
# 2021-02-12  2079.770020  2099.500000  ...             NaN             NaN
#
# [4151 rows x 43 columns]

# %%
def future_close_setup(stock_df, days=1):
  #This function adds a second closing column and moves it up the number of rows
  # needed to predict that many days ahead
  stock_df['Close in ' + str(days) + ' Days'] = stock_df['Close']
  stock_df['Close in ' + str(days) + ' Days'] = stock_df['Close in ' + str(days) + ' Days'].shift(-days)
  return stock_df

# %%
googl_df = future_close_setup(googl_df, 5)
googl_df
# Out:
#                    Open         High  ...  Close in 1Days  Close in 5Days
# Date                                  ...
# 2004-08-19    50.050049    52.082081  ...       54.209209       54.009010
# 2004-08-20    50.555557    54.594597  ...       54.754753       53.128128
# 2004-08-23    55.430431    56.796799  ...       52.487488       51.056057
# 2004-08-24    55.675674    55.855858  ...       53.053055       51.236237
# 2004-08-25    52.532532    54.054054  ...       54.009010       50.175175
# ...                 ...          ...  ...             ...             ...
# 2021-02-08  2100.000000  2115.000000  ...     2075.389893             NaN
# 2021-02-09  2074.800049  2098.510010  ...     2086.479980             NaN
# 2021-02-10  2083.139893  2098.879883  ...     2088.750000             NaN
# 2021-02-11  2091.000000  2094.000000  ...     2095.030029             NaN
# 2021-02-12  2079.770020  2099.500000  ...             NaN             NaN
#
# [4151 rows x 43 columns]
